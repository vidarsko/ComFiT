# %%
import sys
sys.path.append('/Users/jonasronning/Documents/Work/Numerics/Old Projects/ComFiT')

import comfit as cf
import matplotlib.pyplot as plt
import numpy as np

bec = cf.BEC(2,xRes=101,yRes=101,gamma=0.01,dt=0.1)

### setting the system to a homogeneous condensate 
bec.conf_initial_condition_Thomas_Fermi()

#### task 1 and 2
dphidx = np.fft.ifft2(bec.dif[0]*bec.psi_f)

bec.plot_complex_field(dphidx)
plt.show()

# %%
# task 3
bec.evolve_dGPE(50)

bec.plot_field(np.abs(bec.psi)**2,cmap_symmetric=False,colormap = 'winter')
plt.show()
# Out:
# evolving the dGPE: 100%|███████████████████████| 50/50 [00:00<00:00, 690.15it/s]

# %%
#Task 4
bec.conf_insert_vortex_dipole( )

bec.evolve_relax_BEC( 10) 

bec.plot_field(np.abs(bec.psi)**2,cmap_symmetric=False,colormap = 'winter' )
plt.show()
# Out:
# Relaxing the BEC...
# evolving the dGPE: 100%|███████████████████████| 10/10 [00:00<00:00, 258.64it/s]

# %%
psi_old = bec.psi
N=10
bec.evolve_dGPE(N)
dt_psi = (bec.psi-psi_old)/(N*bec.dt)



nodes = bec.calc_vortex_nodes() 

ax=bec.plot_field(np.abs(bec.psi)**2,cmap_symmetric=False,colormap = 'gray')
bec.plot_vortex_nodes(nodes,ax)
plt.show()
# Out:
# evolving the dGPE: 100%|███████████████████████| 10/10 [00:00<00:00, 628.69it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       3 bec.evolve_dGPE(N)
#       4 dt_psi = (bec.psi-psi_old)/(N*bec.dt)
# ----> 8 nodes = bec.calc_vortex_nodes()
#      10 ax=bec.plot_field(np.abs(bec.psi)**2,cmap_symmetric=False,colormap = 'gray')
#      11 bec.plot_vortex_nodes(nodes,ax)
#
# File ~/Documents/Work/Numerics/Old Projects/ComFiT/comfit/models/bose_einstein_condensate.py:488, in BEC.calc_vortex_nodes(self, dt_psi)
#     485 rho_max_index = np.unravel_index(np.argmax(np.abs(rho)), rho.shape)
#     487 # Integrate the defect density around this point (i.e. in a disk around)
# --> 488 disk = self.calc_region_disk(rho_max_index,
#     489                              position = [self.x[rho_max_index[0],0],self.y[0,rho_max_index[1]]],
#     490                              radius=1)
#     491 charge = self.calc_integrate_field(rho, disk)
#     493 # self.plot_field(rho)
#     494 # plt.show()
#
# TypeError: BaseSystem.calc_region_disk() got multiple values for argument 'position'
