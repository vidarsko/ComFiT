# %%
import comfit as cf
import numpy as np
import matplotlib.pyplot as plt

bec = cf.BoseEinsteinCondensate(3,xRes=51,yRes=51,zRes=51)
bec.conf_insert_vortex_ring()
bec.evolve_relax(300)
bec.plot_field(np.abs(bec.psi)**2)
# Out:
# [0. 0. 1.]
# Relaxing the BoseEinsteinCondensate...
# evolving the dGPE: 100%|██████████| 300/300 [00:22<00:00, 13.17it/s]
# <Axes3D: >

# %%
bec.plot_field(np.abs(bec.psi))
# Out:
# Hello
# <Axes3D: >

# %%
rho_abs = np.sqrt(rho[0]**2 + rho[1]**2 + rho[2]**2)

# %%
print(np.sum(rho[0]-rho[1]))
# Out:
# 0.0

# %%
# Out:
# 3
